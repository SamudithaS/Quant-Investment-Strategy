# %% [markdown]
# ## Portfolio construction & Optimization

# %%
#Importing necessary librarie
import os
import sys
import numpy as np
import pandas as pd
import gymnasium as gym
from gymnasium import spaces
from stable_baselines3 import PPO

# %%
#Data Configuration
DATA_DIR = "SLTOP100/"
EQUITY_SCORES_FILE = 'SLTOP100 company_scores.csv'
TBILL_FILE = 'tbill.csv'
TBOND_FILE = 'tbonds.csv'
RISK_AVERSION = 1.0        # Risk penalty weight
TRAIN_STEPS = 100_000      # RL training timesteps

#Clean numeric data
def clean_numeric(series: pd.Series) -> pd.Series:
    num = pd.to_numeric(series.astype(str).str.replace(',', ''), errors='coerce')
    return num.ffill().bfill()

def find_date_column(columns) -> str:
    for col in columns:
        if any(keyword in col.lower() for keyword in ['date', 'week', 'time']):
            return col
    return list(columns)[0]

# %%
#Data Loading

#Equity
def load_equity_returns(data_dir: str, scores_file: str, top_n: int = 20) -> pd.DataFrame:
    scores = pd.read_csv(scores_file, index_col=0)
    tickers = scores['score'].sort_values(ascending=False).head(top_n).index.tolist()
    
    price_dfs = {}
    for ticker in tickers:
        path = os.path.join(data_dir, f"{ticker}.csv")
        df = pd.read_csv(path, dtype=str)
        df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
        df = df.set_index('Trade Date').sort_index()
        df = df[~df.index.duplicated(keep='last')]
        df['Close (Rs.)'] = clean_numeric(df['Close (Rs.)'])
        price_dfs[ticker] = df['Close (Rs.)']
    
    prices = pd.DataFrame(price_dfs)
    daily_returns = prices.pct_change(fill_method=None).dropna()
    weekly_returns = (1 + daily_returns).resample('W').apply(lambda x: (1 + x).prod() - 1).dropna()
    return weekly_returns

#Gov securities
def load_historical_bond_returns(tbill_file: str, tbond_file: str) -> pd.DataFrame:
    def process_file(file_path: str) -> pd.DataFrame:
        df = pd.read_csv(file_path)
        df.columns = df.columns.str.strip()
        date_col = find_date_column(df.columns)
        df[date_col] = pd.to_datetime(df[date_col], errors='coerce')
        df = df.set_index(date_col).sort_index()
        df = df[~df.index.duplicated(keep='last')]
        for col in df.columns:
            df[col] = clean_numeric(df[col]) / 100.0  # convert yields to decimal
        return df.resample('W').ffill()
    
    tbill = process_file(tbill_file)
    tbond = process_file(tbond_file)
    rates = pd.concat([tbill, tbond], axis=1).dropna()
    bond_returns = rates.diff().dropna()
    return bond_returns

# %%
#Loading Data
eq_returns = load_equity_returns(DATA_DIR, EQUITY_SCORES_FILE)
bond_returns = load_historical_bond_returns(TBILL_FILE, TBOND_FILE)

#Cleaning and aligning
for df in [eq_returns, bond_returns]:
    df.dropna(how='all', inplace=True)

returns = eq_returns.join(bond_returns, how='inner').dropna(how='all')
if returns.empty:
    raise ValueError(
        f"No overlap found: equities={eq_returns.shape[0]} rows, bonds={bond_returns.shape[0]} rows."
    )

print(f"Using {returns.shape[0]} weeks and {returns.shape[1]} assets.")
# Out:
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# C:\Users\Samudhitha\AppData\Local\Temp\ipykernel_2960\501381302.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Trade Date'] = pd.to_datetime(df['Trade Date'], dayfirst=True, errors='coerce')
# Using 156 weeks and 36 assets.

# %%
#Portffolio Environment

class PortfolioEnv(gym.Env):
    metadata = {'render_modes': ['human']}

    def __init__(self, returns: pd.DataFrame, risk_aversion: float = 1.0):
        super().__init__()
        self.returns = returns.values
        self.n_assets = self.returns.shape[1]
        self.risk_aversion = risk_aversion
        self.max_steps = len(self.returns) - 1
        
        self.action_space = spaces.Box(low=0, high=1, shape=(self.n_assets,), dtype=np.float32)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.n_assets,), dtype=np.float32)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        return self.returns[self.current_step], {}

    def step(self, action):
        w = np.clip(action, 0, None)
        w /= (w.sum() + 1e-8)  # normalize weights
        r = float(self.returns[self.current_step + 1] @ w)

        start_idx = max(0, self.current_step - 20)
        window = self.returns[start_idx:self.current_step + 1]
        risk = 0.0 if window.shape[0] < 2 else float(w @ np.cov(window.T) @ w)

        reward = r - self.risk_aversion * risk

        self.current_step += 1
        done = self.current_step >= self.max_steps
        obs = self.returns[self.current_step] if not done else np.zeros(self.n_assets)
        
        return obs, reward, done, False, {'ret': r, 'risk': risk}

    def render(self): pass

# %%
#Training PPO Agent
env = PortfolioEnv(returns, RISK_AVERSION)
model = PPO('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=TRAIN_STEPS)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 155       |
# |    ep_rew_mean     | -6.42e+04 |
# | time/              |           |
# |    fps             | 1791      |
# |    iterations      | 1         |
# |    time_elapsed    | 1         |
# |    total_timesteps | 2048      |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -6.57e+04    |
# | time/                   |              |
# |    fps                  | 1063         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0060878387 |
# |    clip_fraction        | 0.0538       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.1        |
# |    explained_variance   | 4.86e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13e+08     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0154      |
# |    std                  | 1            |
# |    value_loss           | 1.55e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -6.38e+04    |
# | time/                   |              |
# |    fps                  | 1027         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0059516225 |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.1        |
# |    explained_variance   | 0.000249     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.11e+07     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0155      |
# |    std                  | 1            |
# |    value_loss           | 1.77e+08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -6.17e+04   |
# | time/                   |             |
# |    fps                  | 948         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.004953242 |
# |    clip_fraction        | 0.0355      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.1       |
# |    explained_variance   | 0.000109    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.2e+07     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 1           |
# |    value_loss           | 1.24e+08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -6.12e+04   |
# | time/                   |             |
# |    fps                  | 921         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004844389 |
# |    clip_fraction        | 0.0332      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.1       |
# |    explained_variance   | 4.14e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.05e+07    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 1           |
# |    value_loss           | 1.1e+08     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -6.07e+04   |
# | time/                   |             |
# |    fps                  | 938         |
# |    iterations           | 6           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004343833 |
# |    clip_fraction        | 0.0244      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.1       |
# |    explained_variance   | 1.79e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.51e+07    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 1           |
# |    value_loss           | 1.34e+08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -6.06e+04    |
# | time/                   |              |
# |    fps                  | 946          |
# |    iterations           | 7            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0056653935 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.1        |
# |    explained_variance   | 1.05e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.67e+07     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0148      |
# |    std                  | 1            |
# |    value_loss           | 1.24e+08     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 155       |
# |    ep_rew_mean          | -6.06e+04 |
# | time/                   |           |
# |    fps                  | 959       |
# |    iterations           | 8         |
# |    time_elapsed         | 17        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.005704  |
# |    clip_fraction        | 0.0389    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -51.1     |
# |    explained_variance   | 6.56e-06  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 9.58e+07  |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -0.0134   |
# |    std                  | 1         |
# |    value_loss           | 1.35e+08  |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -6.01e+04    |
# | time/                   |              |
# |    fps                  | 972          |
# |    iterations           | 9            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0043584523 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.1        |
# |    explained_variance   | 4.23e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.86e+07     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0104      |
# |    std                  | 1            |
# |    value_loss           | 1.5e+08      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -6.01e+04   |
# | time/                   |             |
# |    fps                  | 927         |
# |    iterations           | 10          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005076308 |
# |    clip_fraction        | 0.0276      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.1       |
# |    explained_variance   | 2.8e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.15e+07    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 1           |
# |    value_loss           | 1.39e+08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -5.97e+04   |
# | time/                   |             |
# |    fps                  | 907         |
# |    iterations           | 11          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005421199 |
# |    clip_fraction        | 0.0366      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.1       |
# |    explained_variance   | 1.91e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.93e+07    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 1           |
# |    value_loss           | 1.74e+08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -6.05e+04    |
# | time/                   |              |
# |    fps                  | 907          |
# |    iterations           | 12           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0062318505 |
# |    clip_fraction        | 0.0476       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.1        |
# |    explained_variance   | 1.97e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.5e+07      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0157      |
# |    std                  | 1            |
# |    value_loss           | 1.13e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -5.98e+04    |
# | time/                   |              |
# |    fps                  | 911          |
# |    iterations           | 13           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0051380554 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.1        |
# |    explained_variance   | 1.25e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.11e+07     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0118      |
# |    std                  | 1            |
# |    value_loss           | 1.46e+08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -5.93e+04   |
# | time/                   |             |
# |    fps                  | 917         |
# |    iterations           | 14          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005778278 |
# |    clip_fraction        | 0.0438      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.1       |
# |    explained_variance   | 1.07e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.65e+07    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 1           |
# |    value_loss           | 1.01e+08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -5.96e+04    |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 15           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0041482765 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.1        |
# |    explained_variance   | 8.94e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.78e+07     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0106      |
# |    std                  | 1            |
# |    value_loss           | 1.21e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -5.78e+04    |
# | time/                   |              |
# |    fps                  | 925          |
# |    iterations           | 16           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0053689927 |
# |    clip_fraction        | 0.0392       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.1        |
# |    explained_variance   | 5.96e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.68e+07     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0136      |
# |    std                  | 1            |
# |    value_loss           | 1.4e+08      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -5.77e+04    |
# | time/                   |              |
# |    fps                  | 929          |
# |    iterations           | 17           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0058219293 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.1        |
# |    explained_variance   | 5.96e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.86e+07     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0159      |
# |    std                  | 1            |
# |    value_loss           | 1.14e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -5.58e+04    |
# | time/                   |              |
# |    fps                  | 928          |
# |    iterations           | 18           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0062759863 |
# |    clip_fraction        | 0.045        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.1        |
# |    explained_variance   | 4.77e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.08e+07     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0144      |
# |    std                  | 1            |
# |    value_loss           | 1.05e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -5.6e+04     |
# | time/                   |              |
# |    fps                  | 928          |
# |    iterations           | 19           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0057533486 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.2        |
# |    explained_variance   | 3.58e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.43e+07     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.014       |
# |    std                  | 1            |
# |    value_loss           | 1.16e+08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -5.53e+04    |
# | time/                   |              |
# |    fps                  | 928          |
# |    iterations           | 20           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0054691676 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.2        |
# |    explained_variance   | 2.38e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.42e+07     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.014       |
# |    std                  | 1            |
# |    value_loss           | 1.25e+08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -5.57e+04   |
# | time/                   |             |
# |    fps                  | 919         |
# |    iterations           | 21          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.006210538 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.72e+07    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 1           |
# |    value_loss           | 1.04e+08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -5.43e+04   |
# | time/                   |             |
# |    fps                  | 913         |
# |    iterations           | 22          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005546117 |
# |    clip_fraction        | 0.044       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.23e+07    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 1           |
# |    value_loss           | 1.18e+08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -5.36e+04   |
# | time/                   |             |
# |    fps                  | 895         |
# |    iterations           | 23          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004614206 |
# |    clip_fraction        | 0.0294      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.72e+07    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 1           |
# |    value_loss           | 1.05e+08    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -5.35e+04   |
# | time/                   |             |
# |    fps                  | 866         |
# |    iterations           | 24          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006263561 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.58e+07    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 1           |
# |    value_loss           | 9.05e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -5.39e+04    |
# | time/                   |              |
# |    fps                  | 852          |
# |    iterations           | 25           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0050660735 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.2        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.95e+07     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0134      |
# |    std                  | 1            |
# |    value_loss           | 9.92e+07     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 155        |
# |    ep_rew_mean          | -5.26e+04  |
# | time/                   |            |
# |    fps                  | 834        |
# |    iterations           | 26         |
# |    time_elapsed         | 63         |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.00570451 |
# |    clip_fraction        | 0.035      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -51.2      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.94e+07   |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0136    |
# |    std                  | 1          |
# |    value_loss           | 1.08e+08   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -5.19e+04    |
# | time/                   |              |
# |    fps                  | 817          |
# |    iterations           | 27           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0057863183 |
# |    clip_fraction        | 0.0443       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.2        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.36e+07     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0142      |
# |    std                  | 1            |
# |    value_loss           | 9.22e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -5.1e+04    |
# | time/                   |             |
# |    fps                  | 804         |
# |    iterations           | 28          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.005908684 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.29e+07    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 1           |
# |    value_loss           | 1.05e+08    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 155       |
# |    ep_rew_mean          | -5.21e+04 |
# | time/                   |           |
# |    fps                  | 799       |
# |    iterations           | 29        |
# |    time_elapsed         | 74        |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 0.0052784 |
# |    clip_fraction        | 0.0337    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -51.2     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.1e+07   |
# |    n_updates            | 280       |
# |    policy_gradient_loss | -0.0119   |
# |    std                  | 1         |
# |    value_loss           | 9.21e+07  |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -5.16e+04    |
# | time/                   |              |
# |    fps                  | 789          |
# |    iterations           | 30           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0052197836 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.2        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.59e+07     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.013       |
# |    std                  | 1.01         |
# |    value_loss           | 1.4e+08      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -5.17e+04   |
# | time/                   |             |
# |    fps                  | 774         |
# |    iterations           | 31          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.004534686 |
# |    clip_fraction        | 0.0316      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.39e+07    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 1           |
# |    value_loss           | 9e+07       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -5.24e+04    |
# | time/                   |              |
# |    fps                  | 772          |
# |    iterations           | 32           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0050456263 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.3        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.4e+07      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0133      |
# |    std                  | 1.01         |
# |    value_loss           | 9.81e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -5.09e+04    |
# | time/                   |              |
# |    fps                  | 771          |
# |    iterations           | 33           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0055369157 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.3        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.2e+07      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0139      |
# |    std                  | 1            |
# |    value_loss           | 1.19e+08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -5.1e+04    |
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 34          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006232665 |
# |    clip_fraction        | 0.0446      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.28e+07    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 1           |
# |    value_loss           | 8.22e+07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -5.17e+04   |
# | time/                   |             |
# |    fps                  | 775         |
# |    iterations           | 35          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.006192755 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.39e+07    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 1           |
# |    value_loss           | 8.69e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -5.11e+04    |
# | time/                   |              |
# |    fps                  | 779          |
# |    iterations           | 36           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0056429524 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.2        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.62e+07     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0151      |
# |    std                  | 1            |
# |    value_loss           | 1.35e+08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -4.98e+04   |
# | time/                   |             |
# |    fps                  | 783         |
# |    iterations           | 37          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.006591838 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.56e+07    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 1           |
# |    value_loss           | 7.42e+07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -4.93e+04   |
# | time/                   |             |
# |    fps                  | 785         |
# |    iterations           | 38          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.006077987 |
# |    clip_fraction        | 0.0454      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.51e+07    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 1           |
# |    value_loss           | 7.53e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -4.84e+04    |
# | time/                   |              |
# |    fps                  | 788          |
# |    iterations           | 39           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0054293927 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.2        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.39e+07     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 1            |
# |    value_loss           | 8.57e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -4.73e+04   |
# | time/                   |             |
# |    fps                  | 791         |
# |    iterations           | 40          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006209747 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.7e+07     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.016      |
# |    std                  | 1           |
# |    value_loss           | 8.67e+07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -4.76e+04   |
# | time/                   |             |
# |    fps                  | 795         |
# |    iterations           | 41          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.005951524 |
# |    clip_fraction        | 0.0448      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.43e+07    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 1           |
# |    value_loss           | 6.13e+07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -4.71e+04   |
# | time/                   |             |
# |    fps                  | 798         |
# |    iterations           | 42          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006187205 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.72e+07    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 1           |
# |    value_loss           | 8.92e+07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -4.61e+04   |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 43          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.007458035 |
# |    clip_fraction        | 0.0601      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.67e+07    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 1           |
# |    value_loss           | 8.52e+07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -4.71e+04   |
# | time/                   |             |
# |    fps                  | 799         |
# |    iterations           | 44          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006495306 |
# |    clip_fraction        | 0.0502      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.09e+07    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 1           |
# |    value_loss           | 8.43e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -4.7e+04     |
# | time/                   |              |
# |    fps                  | 802          |
# |    iterations           | 45           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0046747136 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.2        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.78e+07     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 1.01         |
# |    value_loss           | 1.01e+08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -4.7e+04    |
# | time/                   |             |
# |    fps                  | 804         |
# |    iterations           | 46          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.005912112 |
# |    clip_fraction        | 0.0553      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.68e+07    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 1           |
# |    value_loss           | 7.56e+07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -4.65e+04   |
# | time/                   |             |
# |    fps                  | 807         |
# |    iterations           | 47          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.006475144 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -51.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.27e+07    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 1           |
# |    value_loss           | 9.19e+07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -4.72e+04    |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 48           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0059272526 |
# |    clip_fraction        | 0.0513       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.2        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.19e+07     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0146      |
# |    std                  | 1            |
# |    value_loss           | 6.49e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 155          |
# |    ep_rew_mean          | -4.68e+04    |
# | time/                   |              |
# |    fps                  | 811          |
# |    iterations           | 49           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0079826955 |
# |    clip_fraction        | 0.0712       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -51.2        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.04e+07     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0179      |
# |    std                  | 1            |
# |    value_loss           | 8.16e+07     |
# ------------------------------------------

# %%
#Portfolio Evaluation
obs, _ = env.reset()
weights_hist, ret_hist = [], []

for _ in range(env.max_steps):
    action, _ = model.predict(obs, deterministic=True)
    obs, _, done, _, info = env.step(action)
    
    w = np.clip(action, 0, None)
    w /= (w.sum() + 1e-8)
    
    weights_hist.append(w)
    ret_hist.append(info['ret'])
    
    if done:
        break

# %%
#Save results
weights_df = pd.DataFrame(weights_hist, index=returns.index[1:], columns=returns.columns)
perf_df = pd.DataFrame({'portfolio_return': ret_hist}, index=returns.index[1:])

weights_df.to_csv('rl_portfolio_weights.csv')
perf_df.to_csv('rl_portfolio_performance.csv')

print("Saved portfolio weights & performance.")
# Out:
# Saved portfolio weights & performance.
